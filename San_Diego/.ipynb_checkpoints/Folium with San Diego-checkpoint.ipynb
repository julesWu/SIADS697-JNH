# %%
import pandas as pd
import sys
import scipy
import numpy as np
try:
    import folium
except:
    # !{sys.executable} -m pip install folium
    import folium
from folium import plugins
from folium.plugins import MarkerCluster
try:
    import altair as alt
except:
    # !{sys.executable} -m pip install altair
    import altair as alt

# %%
airbnb_data = pd.read_csv('airbnb/detailed_listings.csv')
airbnb_data['count'] = 1
airbnb_data
# Out:
#             id                            listing_url       scrape_id  \
# 0         5570      https://www.airbnb.com/rooms/5570  20210714194825
# 1        29967     https://www.airbnb.com/rooms/29967  20210714194825
# 2        38245     https://www.airbnb.com/rooms/38245  20210714194825
# 3        54001     https://www.airbnb.com/rooms/54001  20210714194825
# 4        62274     https://www.airbnb.com/rooms/62274  20210714194825
# ...        ...                                    ...             ...
# 9094  51025904  https://www.airbnb.com/rooms/51025904  20210714194825
# 9095  51027262  https://www.airbnb.com/rooms/51027262  20210714194825
# 9096  51033701  https://www.airbnb.com/rooms/51033701  20210714194825
# 9097  51034402  https://www.airbnb.com/rooms/51034402  20210714194825
# 9098  51036524  https://www.airbnb.com/rooms/51036524  20210714194825
#
#      last_scraped                                               name  \
# 0      2021-07-14                      Ocean front condo on the sand
# 1      2021-07-14                   Great home, 10 min walk to Beach
# 2      2021-07-15                         Point Loma: Den downstairs
# 3      2021-07-15       La Jolla Cottage Blocks to Ocn; 2Bdms, 1Bth.
# 4      2021-07-15                 charming, colorful, close to beach
# ...           ...                                                ...
# 9094   2021-07-14             Studio Space only steps from the beach
# 9095   2021-07-14   Studio with Private Entrance next to Balboa Park
# 9096   2021-07-15   Professionally maintained apt | 2BR in San Diego
# 9097   2021-07-14       Live + Work + Stay + Easy | 1BR in San Diego
# 9098   2021-07-15  High Rise Penthouse-Near Padres Petco Park- Ea...
#
#                                             description  \
# 0     Missionbeachretreat.   Great Ocean Front Condo...
# 1     This 2 bedroom, 2 full bathroom home offers al...
# 2     Stay in a 1928 Spanish Style home.  Den is dow...
# 3     Separate charming cottage behind main home, 2 ...
# 4     Modern, cozy, artsy, and european in a lush ga...
# ...                                                 ...
# 9094  This is a small studio in the heart of mission...
# 9095                                                NaN
# 9096  Stay for 31+ nights (minimum nights and rates ...
# 9097  Stay for 30+ nights (minimum nights and rates ...
# 9098  Gorgeous Penthouse condo located on the 11th f...
#
#                                   neighborhood_overview  \
# 0     While some may compare San Diego’s Mission Bea...
# 1                                                   NaN
# 2     This neighborhood is an expensive, high-end Po...
# 3     Tranquility, stately trees, meditative, zen-fu...
# 4     We are in walking distance to Starbucks, Trade...
# ...                                                 ...
# 9094                                                NaN
# 9095                                                NaN
# 9096                                                NaN
# 9097                                                NaN
# 9098                                                NaN
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/d3342744-140a...       8435
# 1     https://a0.muscache.com/pictures/76103867/c9b5...     129123
# 2     https://a0.muscache.com/pictures/f3073822-e493...     164137
# 3     https://a0.muscache.com/pictures/47035b04-633c...     252692
# 4     https://a0.muscache.com/pictures/84577734/93ca...     302986
# ...                                                 ...        ...
# 9094  https://a0.muscache.com/pictures/db889d15-55b1...  359922483
# 9095  https://a0.muscache.com/pictures/af5bbe76-2d46...  408623755
# 9096  https://a0.muscache.com/pictures/a4re/floorpla...  368944610
# 9097  https://a0.muscache.com/pictures/a4re/floorpla...  359066913
# 9098  https://a0.muscache.com/pictures/2913442f-0d47...   63806328
#
#                                          host_url  ... review_scores_location  \
# 0          https://www.airbnb.com/users/show/8435  ...                    NaN
# 1        https://www.airbnb.com/users/show/129123  ...                   4.85
# 2        https://www.airbnb.com/users/show/164137  ...                   4.60
# 3        https://www.airbnb.com/users/show/252692  ...                   4.97
# 4        https://www.airbnb.com/users/show/302986  ...                   4.87
# ...                                           ...  ...                    ...
# 9094  https://www.airbnb.com/users/show/359922483  ...                    NaN
# 9095  https://www.airbnb.com/users/show/408623755  ...                    NaN
# 9096  https://www.airbnb.com/users/show/368944610  ...                    NaN
# 9097  https://www.airbnb.com/users/show/359066913  ...                    NaN
# 9098   https://www.airbnb.com/users/show/63806328  ...                    NaN
#
#      review_scores_value license instant_bookable  \
# 0                    NaN     NaN                f
# 1                   4.81     NaN                f
# 2                   4.39     NaN                f
# 3                   4.88     NaN                f
# 4                   4.80     NaN                f
# ...                  ...     ...              ...
# 9094                 NaN     NaN                f
# 9095                 NaN     NaN                t
# 9096                 NaN     NaN                t
# 9097                 NaN     NaN                t
# 9098                 NaN     NaN                f
#
#      calculated_host_listings_count  \
# 0                                 3
# 1                                 5
# 2                                 3
# 3                                 2
# 4                                 2
# ...                             ...
# 9094                              1
# 9095                             35
# 9096                             12
# 9097                             84
# 9098                              7
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              3
# 1                                              5
# 2                                              0
# 3                                              1
# 4                                              2
# ...                                          ...
# 9094                                           1
# 9095                                          34
# 9096                                          12
# 9097                                          84
# 9098                                           7
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               0
# 2                                               3
# 3                                               1
# 4                                               0
# ...                                           ...
# 9094                                            0
# 9095                                            1
# 9096                                            0
# 9097                                            0
# 9098                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month count
# 0                                              0               NaN     1
# 1                                              0              0.49     1
# 2                                              0              1.46     1
# 3                                              0              5.59     1
# 4                                              0              6.15     1
# ...                                          ...               ...   ...
# 9094                                           0               NaN     1
# 9095                                           0               NaN     1
# 9096                                           0               NaN     1
# 9097                                           0               NaN     1
# 9098                                           0               NaN     1
#
# [9099 rows x 75 columns]

# %%
usapoi_data = pd.read_csv('poi_factory/poi_sd_data.csv')
usapoi_data
# Out:
#      longitude  latitude                                information  \
# 0   -116.22777  33.71504           INDIO CA 92201\r\n(760) 342-8138
# 1   -116.29458  33.71358       LA QUINTA CA 92253\r\n(760) 343-7112
# 2   -116.29703  33.76075     PALM DESERT CA 92211\r\n(760) 346-8571
# 3   -116.37430  33.72141     PALM DESERT CA 92260\r\n(760) 346-8571
# 4   -116.38835  33.80823  THOUSAND PALMS CA 92276\r\n(951) 233-8581
# ..         ...       ...                                        ...
# 859 -117.13874  32.62574                        Silver Strand Beach
# 860 -117.13250  32.57600                             Imperial Beach
# 861 -117.26260  32.80490                           Tourmaline Beach
# 862 -117.21600  32.77410                                   Stinkies
# 863 -117.24010  32.78490                                   Sail Bay
#
#                            location
# 0          ARCO - 82338 HIGHWAY 111
# 1    ARCO - 46150 WASHINGTON STREET
# 2            ARCO - 78355 VARNER RD
# 3          ARCO - 73980 HIGHWAY 111
# 4         ARCO - 32975 MONTEREY AVE
# ..                              ...
# 859                             NaN
# 860                             NaN
# 861                             NaN
# 862                             NaN
# 863                             NaN
#
# [864 rows x 4 columns]

# %%
map1 = folium.Map(location=[37, -121], zoom_start=3)

stationArr = airbnb_data[['latitude', 'longitude', 'count']].values


#Commented out to save space. Make sure your computer can handle folium charts!
map1.add_children(plugins.HeatMap(stationArr, radius=15))

mc = MarkerCluster()

for index, row in usapoi_data.iterrows():
    mc.add_child(folium.Marker(location=[row['latitude'], row['longitude']]))
    
map1.add_child(mc)

#Illustrating clusters (count of individual places rows) with heatmap
map1
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
#   import sys
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### However, what about distance?

# %%
only_places = airbnb_data[['longitude', 'latitude']].reset_index(drop=True)
pd.Series(only_places.iloc[0])
# Out:
# longitude   -117.25313
# latitude      32.78481
# Name: 0, dtype: float64

# %%
usapoi_data[['longitude', 'latitude']]
# Out:
#      longitude  latitude
# 0   -116.22777  33.71504
# 1   -116.29458  33.71358
# 2   -116.29703  33.76075
# 3   -116.37430  33.72141
# 4   -116.38835  33.80823
# ..         ...       ...
# 859 -117.13874  32.62574
# 860 -117.13250  32.57600
# 861 -117.26260  32.80490
# 862 -117.21600  32.77410
# 863 -117.24010  32.78490
#
# [864 rows x 2 columns]

# %%
# Function to get a "distance number" between one location to another based on long/lat
def haversine_vectorize(lon1, lat1, lon2, lat2):

    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    newlon = lon2 - lon1
    newlat = lat2 - lat1

    haver_formula = np.sin(newlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(newlon/2.0)**2

    dist = 2 * np.arcsin(np.sqrt(haver_formula ))
    km = 6367 * dist #6367 for distance in KM for miles use 3958
    return km

# %%
test_list = []
for num in range(0, len(usapoi_data)):
    test_list.append(haversine_vectorize(only_places.loc[0]['longitude'], only_places.loc[0]['latitude'],
                       usapoi_data[['longitude', 'latitude']].loc[num]['longitude'],
                       usapoi_data[['longitude', 'latitude']].loc[num]['latitude']))

# %%
len([a for a in test_list if a < 100])
# Out:
# 637

# %%
# Run through and receive the closest attractions within each listing
def get_number_of_close_attractions(area_series):
    all_distances = []
    for num in range(0, len(usapoi_data)):
        all_distances.append(haversine_vectorize(area_series['longitude'], area_series['latitude'],
                           usapoi_data[['longitude', 'latitude']].loc[num]['longitude'],
                           usapoi_data[['longitude', 'latitude']].loc[num]['latitude']))

    return len([close_stuff for close_stuff in all_distances if close_stuff < 100])

# %%
import tqdm

# %%
listing_1 = pd.read_csv('airbnb/listings1.csv')
only_places1 = listing_1[['longitude', 'latitude']].reset_index(drop=True)

listing_2 = pd.read_csv('airbnb/listings2.csv')
only_places2 = listing_2[['longitude', 'latitude']].reset_index(drop=True)

listing_3 = pd.read_csv('airbnb/listings3.csv')
only_places3 = listing_3[['longitude', 'latitude']].reset_index(drop=True)

# %%
close_attractions3 = []

for num in tqdm.tqdm(range(0, len(only_places3))):
    close_attractions3.append(get_number_of_close_attractions(only_places3.loc[num]))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2752/2752 [49:58<00:00,  1.09s/it]

# %%
# only_places1['closeness_attactions'] = close_attractions1
# only_places1.to_csv('test1_closeness.csv')

# %%
# only_places2['closeness_attactions'] = close_attractions2
# only_places2.to_csv('test2_closeness.csv')

# %%
# only_places3['closeness_attactions'] = close_attractions3
# only_places3.to_csv('test3_closeness.csv')
