# %%
import pandas as pd
import sys
import scipy
import numpy as np
try:
    import folium
except:
    # !{sys.executable} -m pip install folium
    import folium
from folium import plugins
from folium.plugins import MarkerCluster
try:
    import altair as alt
except:
    # !{sys.executable} -m pip install altair
    import altair as alt

# %%
airbnb_data = pd.read_csv('airbnb/detailed_listings.csv')
airbnb_data['count'] = 1
airbnb_data
# Out:
#             id                            listing_url       scrape_id  \
# 0          958       https://www.airbnb.com/rooms/958  20210703181755
# 1         5858      https://www.airbnb.com/rooms/5858  20210703181755
# 2         7918      https://www.airbnb.com/rooms/7918  20210703181755
# 3         8142      https://www.airbnb.com/rooms/8142  20210703181755
# 4         8339      https://www.airbnb.com/rooms/8339  20210703181755
# ...        ...                                    ...             ...
# 6638  50795717  https://www.airbnb.com/rooms/50795717  20210703181755
# 6639  50795897  https://www.airbnb.com/rooms/50795897  20210703181755
# 6640  50798477  https://www.airbnb.com/rooms/50798477  20210703181755
# 6641  50798706  https://www.airbnb.com/rooms/50798706  20210703181755
# 6642  50798837  https://www.airbnb.com/rooms/50798837  20210703181755
#
#      last_scraped                                               name  \
# 0      2021-07-03              Bright, Modern Garden Unit - 1BR/1BTH
# 1      2021-07-04                                 Creative Sanctuary
# 2      2021-07-04         A Friendly Room - UCSF/USF - San Francisco
# 3      2021-07-04  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4      2021-07-03                    Historic Alamo Square Victorian
# ...           ...                                                ...
# 6638   2021-07-03  4-nites at Wyndham Canterbury for Dreamforce 2021
# 6639   2021-07-03   4-nites @ Wyndham Canterbury for Dreamforce 2021
# 6640   2021-07-03   5-nites @ Wyndham Canterbury for Dreamforce 2021
# 6641   2021-07-03     Dreamforce 2021 - 5-nites @ Wyndham Canterbury
# 6642   2021-07-03    Wyndham Canterbury, 5-nites for Dreamforce 2021
#
#                                             description  \
# 0     Please check local laws re Covid before you re...
# 1     <b>The space</b><br />We live in a large Victo...
# 2     Nice and good public transportation.  7 minute...
# 3     Nice and good public transportation.  7 minute...
# 4     Pls email before booking. <br />Interior featu...
# ...                                                 ...
# 6638  You will appreciate the accommodations at the ...
# 6639  This reservation is for a 4-night stay at Wynd...
# 6640  This reservation is for a 5-night stay at Wynd...
# 6641  This listing is for a 5-night stay at Wyndham ...
# 6642  This reservation is for a 5-night stay at Wynd...
#
#                                   neighborhood_overview  \
# 0     Quiet cul de sac in friendly neighborhood<br /...
# 1     I love how our neighborhood feels quiet but is...
# 2     Shopping old town, restaurants, McDonald, Whol...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6638                                                NaN
# 6639                                                NaN
# 6640                                                NaN
# 6641                                                NaN
# 6642                                                NaN
#
#                                             picture_url   host_id  \
# 0     https://a0.muscache.com/pictures/b7c2a199-4c17...      1169
# 1     https://a0.muscache.com/pictures/17714/3a7aea1...      8904
# 2     https://a0.muscache.com/pictures/26356/8030652...     21994
# 3     https://a0.muscache.com/pictures/27832/3b1f9e5...     21994
# 4     https://a0.muscache.com/pictures/213fbf05-3545...     24215
# ...                                                 ...       ...
# 6638  https://a0.muscache.com/pictures/00fab6d6-d1f2...  40205329
# 6639  https://a0.muscache.com/pictures/678dd87c-3110...  40205329
# 6640  https://a0.muscache.com/pictures/f11f0bda-d0a7...  40205329
# 6641  https://a0.muscache.com/pictures/b9126a1b-977c...  40205329
# 6642  https://a0.muscache.com/pictures/bc057c35-d5a7...  40205329
#
#                                         host_url  ... review_scores_location  \
# 0         https://www.airbnb.com/users/show/1169  ...                   4.98
# 1         https://www.airbnb.com/users/show/8904  ...                   4.77
# 2        https://www.airbnb.com/users/show/21994  ...                   4.73
# 3        https://www.airbnb.com/users/show/21994  ...                   4.63
# 4        https://www.airbnb.com/users/show/24215  ...                   4.94
# ...                                          ...  ...                    ...
# 6638  https://www.airbnb.com/users/show/40205329  ...                    NaN
# 6639  https://www.airbnb.com/users/show/40205329  ...                    NaN
# 6640  https://www.airbnb.com/users/show/40205329  ...                    NaN
# 6641  https://www.airbnb.com/users/show/40205329  ...                    NaN
# 6642  https://www.airbnb.com/users/show/40205329  ...                    NaN
#
#      review_scores_value                    license instant_bookable  \
# 0                   4.78  City Registration Pending                f
# 1                   4.68                        NaN                f
# 2                   4.00                        NaN                f
# 3                   4.63                        NaN                f
# 4                   4.75                STR-0000264                f
# ...                  ...                        ...              ...
# 6638                 NaN                    0394267                t
# 6639                 NaN                    0394267                t
# 6640                 NaN                    0394267                t
# 6641                 NaN                    0394267                t
# 6642                 NaN                    0394267                t
#
#      calculated_host_listings_count  \
# 0                                 1
# 1                                 1
# 2                                 9
# 3                                 9
# 4                                 2
# ...                             ...
# 6638                              7
# 6639                              7
# 6640                              7
# 6641                              7
# 6642                              7
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              1
# 1                                              1
# 2                                              0
# 3                                              0
# 4                                              2
# ...                                          ...
# 6638                                           7
# 6639                                           7
# 6640                                           7
# 6641                                           7
# 6642                                           7
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               0
# 2                                               9
# 3                                               9
# 4                                               0
# ...                                           ...
# 6638                                            0
# 6639                                            0
# 6640                                            0
# 6641                                            0
# 6642                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month count
# 0                                              0              3.48     1
# 1                                              0              0.79     1
# 2                                              0              0.18     1
# 3                                              0              0.10     1
# 4                                              0              0.20     1
# ...                                          ...               ...   ...
# 6638                                           0               NaN     1
# 6639                                           0               NaN     1
# 6640                                           0               NaN     1
# 6641                                           0               NaN     1
# 6642                                           0               NaN     1
#
# [6643 rows x 75 columns]

# %%
usapoi_data = pd.read_csv('poi_factory/poi_sd_data.csv')
usapoi_data
# Out:
#      longitude  latitude                                information  \
# 0   -116.22777  33.71504           INDIO CA 92201\r\n(760) 342-8138
# 1   -116.29458  33.71358       LA QUINTA CA 92253\r\n(760) 343-7112
# 2   -116.29703  33.76075     PALM DESERT CA 92211\r\n(760) 346-8571
# 3   -116.37430  33.72141     PALM DESERT CA 92260\r\n(760) 346-8571
# 4   -116.38835  33.80823  THOUSAND PALMS CA 92276\r\n(951) 233-8581
# ..         ...       ...                                        ...
# 859 -117.13874  32.62574                        Silver Strand Beach
# 860 -117.13250  32.57600                             Imperial Beach
# 861 -117.26260  32.80490                           Tourmaline Beach
# 862 -117.21600  32.77410                                   Stinkies
# 863 -117.24010  32.78490                                   Sail Bay
#
#                            location
# 0          ARCO - 82338 HIGHWAY 111
# 1    ARCO - 46150 WASHINGTON STREET
# 2            ARCO - 78355 VARNER RD
# 3          ARCO - 73980 HIGHWAY 111
# 4         ARCO - 32975 MONTEREY AVE
# ..                              ...
# 859                             NaN
# 860                             NaN
# 861                             NaN
# 862                             NaN
# 863                             NaN
#
# [864 rows x 4 columns]

# %%
map1 = folium.Map(location=[37, -121], zoom_start=3)

stationArr = airbnb_data[['latitude', 'longitude', 'count']].values


#Commented out to save space. Make sure your computer can handle folium charts!
map1.add_children(plugins.HeatMap(stationArr, radius=15))

mc = MarkerCluster()

for index, row in usapoi_data.iterrows():
    mc.add_child(folium.Marker(location=[row['latitude'], row['longitude']]))
    
map1.add_child(mc)

#Illustrating clusters (count of individual places rows) with heatmap
map1
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
#   import sys
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
